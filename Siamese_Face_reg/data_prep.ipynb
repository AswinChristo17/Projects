# %%
import cv2
import uuid

cap = cv2.VideoCapture(0)
while cap.isOpened(): 
    ret, frame = cap.read()
   
    frame = frame[120:120+250,200:200+250, :]
    
    if cv2.waitKey(1) & 0XFF == ord('a'):
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname, frame)
    
    if cv2.waitKey(1) & 0XFF == ord('p'):
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname, frame)
    
    cv2.imshow('Image Collection', frame)
    
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import os

save_directory = 'photos'
os.makedirs(save_directory, exist_ok=True)

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

num_photos = 350
photo_count = 0

print("Press 'q' to quit early.")

while photo_count < num_photos:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame.")
        break

    cv2.imshow('Photo Capture', frame)

    photo_path = os.path.join(save_directory, f'photo_{photo_count+1}.jpg')
    cv2.imwrite(photo_path, frame)
    photo_count += 1
    print(f"Captured photo {photo_count}/{num_photos}")

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

print(f"Finished capturing {photo_count} photos.")
# Out:
# Press 'q' to quit early.
# Captured photo 1/350
# Captured photo 2/350
# Captured photo 3/350
# Captured photo 4/350
# Captured photo 5/350
# Captured photo 6/350
# Captured photo 7/350
# Captured photo 8/350
# Captured photo 9/350
# Captured photo 10/350
# Captured photo 11/350
# Captured photo 12/350
# Captured photo 13/350
# Captured photo 14/350
# Captured photo 15/350
# Captured photo 16/350
# Captured photo 17/350
# Captured photo 18/350
# Captured photo 19/350
# Captured photo 20/350
# Captured photo 21/350
# Captured photo 22/350
# Captured photo 23/350
# Captured photo 24/350
# Captured photo 25/350
# Captured photo 26/350
# Captured photo 27/350
# Captured photo 28/350
# Captured photo 29/350
# Captured photo 30/350
# Captured photo 31/350
# Captured photo 32/350
# Captured photo 33/350
# Captured photo 34/350
# Captured photo 35/350
# Captured photo 36/350
# Captured photo 37/350
# Captured photo 38/350
# Captured photo 39/350
# Captured photo 40/350
# Captured photo 41/350
# Captured photo 42/350
# Captured photo 43/350
# Captured photo 44/350
# Captured photo 45/350
# Captured photo 46/350
# Captured photo 47/350
# Captured photo 48/350
# Captured photo 49/350
# Captured photo 50/350
# Captured photo 51/350
# Captured photo 52/350
# Captured photo 53/350
# Captured photo 54/350
# Captured photo 55/350
# Captured photo 56/350
# Captured photo 57/350
# Captured photo 58/350
# Captured photo 59/350
# Captured photo 60/350
# Captured photo 61/350
# Captured photo 62/350
# Captured photo 63/350
# Captured photo 64/350
# Captured photo 65/350
# Captured photo 66/350
# Captured photo 67/350
# Captured photo 68/350
# Captured photo 69/350
# Captured photo 70/350
# Captured photo 71/350
# Captured photo 72/350
# Captured photo 73/350
# Captured photo 74/350
# Captured photo 75/350
# Captured photo 76/350
# Captured photo 77/350
# Captured photo 78/350
# Captured photo 79/350
# Captured photo 80/350
# Captured photo 81/350
# Captured photo 82/350
# Captured photo 83/350
# Captured photo 84/350
# Captured photo 85/350
# Captured photo 86/350
# Captured photo 87/350
# Captured photo 88/350
# Captured photo 89/350
# Captured photo 90/350
# Captured photo 91/350
# Captured photo 92/350
# Captured photo 93/350
# Captured photo 94/350
# Captured photo 95/350
# Captured photo 96/350
# Captured photo 97/350
# Captured photo 98/350
# Captured photo 99/350
# Captured photo 100/350
# Captured photo 101/350
# Captured photo 102/350
# Captured photo 103/350
# Captured photo 104/350
# Captured photo 105/350
# Captured photo 106/350
# Captured photo 107/350
# Captured photo 108/350
# Captured photo 109/350
# Captured photo 110/350
# Captured photo 111/350
# Captured photo 112/350
# Captured photo 113/350
# Captured photo 114/350
# Captured photo 115/350
# Captured photo 116/350
# Captured photo 117/350
# Captured photo 118/350
# Captured photo 119/350
# Captured photo 120/350
# Captured photo 121/350
# Captured photo 122/350
# Captured photo 123/350
# Captured photo 124/350
# Captured photo 125/350
# Captured photo 126/350
# Captured photo 127/350
# Captured photo 128/350
# Captured photo 129/350
# Captured photo 130/350
# Captured photo 131/350
# Captured photo 132/350
# Captured photo 133/350
# Captured photo 134/350
# Captured photo 135/350
# Captured photo 136/350
# Captured photo 137/350
# Captured photo 138/350
# Captured photo 139/350
# Captured photo 140/350
# Captured photo 141/350
# Captured photo 142/350
# Captured photo 143/350
# Captured photo 144/350
# Captured photo 145/350
# Captured photo 146/350
# Captured photo 147/350
# Captured photo 148/350
# Captured photo 149/350
# Captured photo 150/350
# Captured photo 151/350
# Captured photo 152/350
# Captured photo 153/350
# Captured photo 154/350
# Captured photo 155/350
# Captured photo 156/350
# Captured photo 157/350
# Captured photo 158/350
# Captured photo 159/350
# Captured photo 160/350
# Captured photo 161/350
# Captured photo 162/350
# Captured photo 163/350
# Captured photo 164/350
# Captured photo 165/350
# Captured photo 166/350
# Captured photo 167/350
# Captured photo 168/350
# Captured photo 169/350
# Captured photo 170/350
# Captured photo 171/350
# Captured photo 172/350
# Captured photo 173/350
# Captured photo 174/350
# Captured photo 175/350
# Captured photo 176/350
# Captured photo 177/350
# Captured photo 178/350
# Captured photo 179/350
# Captured photo 180/350
# Captured photo 181/350
# Captured photo 182/350
# Captured photo 183/350
# Captured photo 184/350
# Captured photo 185/350
# Captured photo 186/350
# Captured photo 187/350
# Captured photo 188/350
# Captured photo 189/350
# Captured photo 190/350
# Captured photo 191/350
# Captured photo 192/350
# Captured photo 193/350
# Captured photo 194/350
# Captured photo 195/350
# Captured photo 196/350
# Captured photo 197/350
# Captured photo 198/350
# Captured photo 199/350
# Captured photo 200/350
# Captured photo 201/350
# Captured photo 202/350
# Captured photo 203/350
# Captured photo 204/350
# Captured photo 205/350
# Captured photo 206/350
# Captured photo 207/350
# Captured photo 208/350
# Captured photo 209/350
# Captured photo 210/350
# Captured photo 211/350
# Captured photo 212/350
# Captured photo 213/350
# Captured photo 214/350
# Captured photo 215/350
# Captured photo 216/350
# Captured photo 217/350
# Captured photo 218/350
# Captured photo 219/350
# Captured photo 220/350
# Captured photo 221/350
# Captured photo 222/350
# Captured photo 223/350
# Captured photo 224/350
# Captured photo 225/350
# Captured photo 226/350
# Captured photo 227/350
# Captured photo 228/350
# Captured photo 229/350
# Captured photo 230/350
# Captured photo 231/350
# Captured photo 232/350
# Captured photo 233/350
# Captured photo 234/350
# Captured photo 235/350
# Captured photo 236/350
# Captured photo 237/350
# Captured photo 238/350
# Captured photo 239/350
# Captured photo 240/350
# Captured photo 241/350
# Captured photo 242/350
# Captured photo 243/350
# Captured photo 244/350
# Captured photo 245/350
# Captured photo 246/350
# Captured photo 247/350
# Captured photo 248/350
# Captured photo 249/350
# Captured photo 250/350
# Captured photo 251/350
# Captured photo 252/350
# Captured photo 253/350
# Captured photo 254/350
# Captured photo 255/350
# Captured photo 256/350
# Captured photo 257/350
# Captured photo 258/350
# Captured photo 259/350
# Captured photo 260/350
# Captured photo 261/350
# Captured photo 262/350
# Captured photo 263/350
# Captured photo 264/350
# Captured photo 265/350
# Captured photo 266/350
# Captured photo 267/350
# Captured photo 268/350
# Captured photo 269/350
# Captured photo 270/350
# Captured photo 271/350
# Captured photo 272/350
# Captured photo 273/350
# Captured photo 274/350
# Captured photo 275/350
# Captured photo 276/350
# Captured photo 277/350
# Captured photo 278/350
# Captured photo 279/350
# Captured photo 280/350
# Captured photo 281/350
# Captured photo 282/350
# Captured photo 283/350
# Captured photo 284/350
# Captured photo 285/350
# Captured photo 286/350
# Captured photo 287/350
# Captured photo 288/350
# Captured photo 289/350
# Captured photo 290/350
# Captured photo 291/350
# Captured photo 292/350
# Captured photo 293/350
# Captured photo 294/350
# Captured photo 295/350
# Captured photo 296/350
# Captured photo 297/350
# Captured photo 298/350
# Captured photo 299/350
# Captured photo 300/350
# Captured photo 301/350
# Captured photo 302/350
# Captured photo 303/350
# Captured photo 304/350
# Captured photo 305/350
# Captured photo 306/350
# Captured photo 307/350
# Captured photo 308/350
# Captured photo 309/350
# Captured photo 310/350
# Captured photo 311/350
# Captured photo 312/350
# Captured photo 313/350
# Captured photo 314/350
# Captured photo 315/350
# Captured photo 316/350
# Captured photo 317/350
# Captured photo 318/350
# Captured photo 319/350
# Captured photo 320/350
# Captured photo 321/350
# Captured photo 322/350
# Captured photo 323/350
# Captured photo 324/350
# Captured photo 325/350
# Captured photo 326/350
# Captured photo 327/350
# Captured photo 328/350
# Captured photo 329/350
# Captured photo 330/350
# Captured photo 331/350
# Captured photo 332/350
# Captured photo 333/350
# Captured photo 334/350
# Captured photo 335/350
# Captured photo 336/350
# Captured photo 337/350
# Captured photo 338/350
# Captured photo 339/350
# Captured photo 340/350
# Captured photo 341/350
# Captured photo 342/350
# Captured photo 343/350
# Captured photo 344/350
# Captured photo 345/350
# Captured photo 346/350
# Captured photo 347/350
# Captured photo 348/350
# Captured photo 349/350
# Captured photo 350/350
# Finished capturing 350 photos.
